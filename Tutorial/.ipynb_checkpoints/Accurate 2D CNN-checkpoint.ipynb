# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
from tensorflow.keras.datasets import mnist

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
plt.imshow(X_train[0])

# %%
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
X_train.max()
# Out:
# 255

# %%
X_train = X_train/255.0
X_test = X_test/255.0
X_train[0].shape
# Out:
# (28, 28)

# %%
X_train = X_train.reshape(60000, 28, 28, 1)
X_test = X_test.reshape(10000, 28, 28, 1)
X_train[0].shape
# Out:
# (28, 28, 1)

# %%
input_shape = X_train[0].shape

# %%
model = Sequential()
model.add(Conv2D(
    filters=32,
    kernel_size=(3,3),
    activation='relu',
    input_shape=input_shape
))
model.add(Conv2D(
    filters=64,
    kernel_size=(3,3),
    activation='relu'
))
model.add(MaxPool2D(2,2))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1179776
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, batch_size=128, epochs=10, verbose=1, validation_data=(X_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 79s 1ms/sample - loss: 0.2619 - accuracy: 0.9208 - val_loss: 0.0616 - val_accuracy: 0.9799
# Epoch 2/10
# 60000/60000 [==============================] - 70s 1ms/sample - loss: 0.0928 - accuracy: 0.9726 - val_loss: 0.0394 - val_accuracy: 0.9878
# Epoch 3/10
# 60000/60000 [==============================] - 70s 1ms/sample - loss: 0.0694 - accuracy: 0.9797 - val_loss: 0.0371 - val_accuracy: 0.9882
# Epoch 4/10
# 60000/60000 [==============================] - 66s 1ms/sample - loss: 0.0553 - accuracy: 0.9831 - val_loss: 0.0280 - val_accuracy: 0.9909
# Epoch 5/10
# 60000/60000 [==============================] - 82s 1ms/sample - loss: 0.0487 - accuracy: 0.9850 - val_loss: 0.0341 - val_accuracy: 0.9884
# Epoch 6/10
# 60000/60000 [==============================] - 126s 2ms/sample - loss: 0.0419 - accuracy: 0.9867 - val_loss: 0.0288 - val_accuracy: 0.9899
# Epoch 7/10
# 60000/60000 [==============================] - 116s 2ms/sample - loss: 0.0372 - accuracy: 0.9886 - val_loss: 0.0290 - val_accuracy: 0.9908
# Epoch 8/10
# 60000/60000 [==============================] - 122s 2ms/sample - loss: 0.0349 - accuracy: 0.9887 - val_loss: 0.0252 - val_accuracy: 0.9919
# Epoch 9/10
# 60000/60000 [==============================] - 126s 2ms/sample - loss: 0.0323 - accuracy: 0.9897 - val_loss: 0.0276 - val_accuracy: 0.9917
# Epoch 10/10
# 60000/60000 [==============================] - 107s 2ms/sample - loss: 0.0283 - accuracy: 0.9910 - val_loss: 0.0248 - val_accuracy: 0.9927

# %%
model.evaluate(X_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.024789292251075404, 0.9927]

# %%
def plot_learningCurve(history, epochs):
  # Plot training & validation accuracy values
  epoch_range = range(1, epochs+1)
  plt.plot(epoch_range, history.history['accuracy'])
  plt.plot(epoch_range, history.history['val_accuracy'])
  plt.title('Model accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='upper left')
  plt.show()

  # Plot training & validation loss values
  plt.plot(epoch_range, history.history['loss'])
  plt.plot(epoch_range, history.history['val_loss'])
  plt.title('Model loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Val'], loc='upper left')
  plt.show()

# %%
plot_learningCurve(history, 10)

# %%
history.history
# Out:
# {'loss': [0.2619078960418701,
#   0.09277592686414719,
#   0.06940377400318781,
#   0.05534232456286748,
#   0.04867813836832841,
#   0.041892005892594654,
#   0.037217681876942514,
#   0.03490438973704974,
#   0.03231686512554685,
#   0.028298525995264452],
#  'accuracy': [0.92081666,
#   0.97265,
#   0.97971666,
#   0.9830667,
#   0.9849833,
#   0.9866667,
#   0.98863333,
#   0.98873335,
#   0.9897,
#   0.9910167],
#  'val_loss': [0.061649779815971854,
#   0.03938496292042546,
#   0.037087022538483144,
#   0.027957173325069015,
#   0.03414495693789795,
#   0.028828575392405038,
#   0.028999771952503944,
#   0.02523789575988776,
#   0.027604473151930143,
#   0.02478929149068208],
#  'val_accuracy': [0.9799,
#   0.9878,
#   0.9882,
#   0.9909,
#   0.9884,
#   0.9899,
#   0.9908,
#   0.9919,
#   0.9917,
#   0.9927]}
