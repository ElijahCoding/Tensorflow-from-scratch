# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
imdb = keras.datasets.imdb

# %%
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

# %%
# A dictionary mapping words to an integer index
_word_index = imdb.get_word_index()
word_index = {k:(v+3) for k,v in _word_index.items()}
word_index["<PAD>"] = 0
word_index["<START>"] = 1
word_index["<UNK>"] = 2  # unknown
word_index["<UNUSED>"] = 3

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

# %%
def decode_review(text):
	return " ".join([reverse_word_index.get(i, "?") for i in text])

# %%
print(decode_review(test_data[0]))
# Out:
# <START> please give this one a miss br br <UNK> <UNK> and the rest of the cast rendered terrible performances the show is flat flat flat br br i don't know how michael madison could have allowed this one on his plate he almost seemed to know this wasn't going to work out and his performance was quite <UNK> so all you madison fans give this a miss

# %%
train_data = keras.preprocessing.sequence.pad_sequences(train_data, value=word_index["<PAD>"], padding="post", maxlen=250)

# %%
test_data = keras.preprocessing.sequence.pad_sequences(test_data, value=word_index["<PAD>"], padding="post", maxlen=250)

# %%
model = keras.Sequential()
model.add(keras.layers.Embedding(10000, 16))
model.add(keras.layers.GlobalAveragePooling1D())
model.add(keras.layers.Dense(16, activation="relu"))
model.add(keras.layers.Dense(1, activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 16)          160000
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 16)                272
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,289
# Trainable params: 160,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=["accuracy"])

# %%
x_val = train_data[:10000]
x_train = train_data[10000:]

y_val = train_labels[:10000]
y_train = train_labels[10000:]

# %%
fitModel = model.fit(x_train, y_train, epochs=40, batch_size=512, validation_data=(x_val, y_val), verbose=1)
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/40
# 15000/15000 [==============================] - 1s 75us/sample - loss: 0.6925 - accuracy: 0.5860 - val_loss: 0.6914 - val_accuracy: 0.5405
# Epoch 2/40
# 15000/15000 [==============================] - 0s 20us/sample - loss: 0.6888 - accuracy: 0.5829 - val_loss: 0.6857 - val_accuracy: 0.7088
# Epoch 3/40
# 15000/15000 [==============================] - 0s 22us/sample - loss: 0.6797 - accuracy: 0.7387 - val_loss: 0.6737 - val_accuracy: 0.7378
# Epoch 4/40
# 15000/15000 [==============================] - 0s 24us/sample - loss: 0.6622 - accuracy: 0.7623 - val_loss: 0.6531 - val_accuracy: 0.7621
# Epoch 5/40
# 15000/15000 [==============================] - 0s 27us/sample - loss: 0.6347 - accuracy: 0.7835 - val_loss: 0.6232 - val_accuracy: 0.7778
# Epoch 6/40
# 15000/15000 [==============================] - 0s 22us/sample - loss: 0.5978 - accuracy: 0.8033 - val_loss: 0.5857 - val_accuracy: 0.7943
# Epoch 7/40
# 15000/15000 [==============================] - 0s 24us/sample - loss: 0.5544 - accuracy: 0.8221 - val_loss: 0.5449 - val_accuracy: 0.8039
# Epoch 8/40
# 15000/15000 [==============================] - 0s 23us/sample - loss: 0.5090 - accuracy: 0.8375 - val_loss: 0.5039 - val_accuracy: 0.8230
# Epoch 9/40
# 15000/15000 [==============================] - 0s 21us/sample - loss: 0.4647 - accuracy: 0.8509 - val_loss: 0.4662 - val_accuracy: 0.8349
# Epoch 10/40
# 15000/15000 [==============================] - 0s 23us/sample - loss: 0.4246 - accuracy: 0.8662 - val_loss: 0.4329 - val_accuracy: 0.8449
# Epoch 11/40
# 15000/15000 [==============================] - 0s 24us/sample - loss: 0.3895 - accuracy: 0.8745 - val_loss: 0.4052 - val_accuracy: 0.8518
# Epoch 12/40
# 15000/15000 [==============================] - 0s 22us/sample - loss: 0.3598 - accuracy: 0.8837 - val_loss: 0.3827 - val_accuracy: 0.8574
# Epoch 13/40
# 15000/15000 [==============================] - 0s 22us/sample - loss: 0.3345 - accuracy: 0.8899 - val_loss: 0.3647 - val_accuracy: 0.8625
# Epoch 14/40
# 15000/15000 [==============================] - 0s 21us/sample - loss: 0.3134 - accuracy: 0.8958 - val_loss: 0.3495 - val_accuracy: 0.8660
# Epoch 15/40
# 15000/15000 [==============================] - 0s 21us/sample - loss: 0.2948 - accuracy: 0.8995 - val_loss: 0.3374 - val_accuracy: 0.8716
# Epoch 16/40
# 15000/15000 [==============================] - 0s 22us/sample - loss: 0.2783 - accuracy: 0.9039 - val_loss: 0.3271 - val_accuracy: 0.8739
# Epoch 17/40
# 15000/15000 [==============================] - 0s 27us/sample - loss: 0.2635 - accuracy: 0.9080 - val_loss: 0.3189 - val_accuracy: 0.8766
# Epoch 18/40
# 15000/15000 [==============================] - 0s 22us/sample - loss: 0.2508 - accuracy: 0.9134 - val_loss: 0.3116 - val_accuracy: 0.8795
# Epoch 19/40
# 15000/15000 [==============================] - 0s 21us/sample - loss: 0.2387 - accuracy: 0.9176 - val_loss: 0.3056 - val_accuracy: 0.8801
# Epoch 20/40
# 15000/15000 [==============================] - 0s 21us/sample - loss: 0.2278 - accuracy: 0.9207 - val_loss: 0.3007 - val_accuracy: 0.8814
# Epoch 21/40
# 15000/15000 [==============================] - 0s 21us/sample - loss: 0.2175 - accuracy: 0.9255 - val_loss: 0.2973 - val_accuracy: 0.8818
# Epoch 22/40
# 15000/15000 [==============================] - 0s 21us/sample - loss: 0.2091 - accuracy: 0.9273 - val_loss: 0.2934 - val_accuracy: 0.8830
# Epoch 23/40
# 15000/15000 [==============================] - 0s 21us/sample - loss: 0.2003 - accuracy: 0.9325 - val_loss: 0.2908 - val_accuracy: 0.8825
# Epoch 24/40
# 15000/15000 [==============================] - 0s 22us/sample - loss: 0.1916 - accuracy: 0.9358 - val_loss: 0.2889 - val_accuracy: 0.8848
# Epoch 25/40
# 15000/15000 [==============================] - 0s 22us/sample - loss: 0.1840 - accuracy: 0.9383 - val_loss: 0.2870 - val_accuracy: 0.8854
# Epoch 26/40
# 15000/15000 [==============================] - 0s 20us/sample - loss: 0.1766 - accuracy: 0.9425 - val_loss: 0.2865 - val_accuracy: 0.8858
# Epoch 27/40
# 15000/15000 [==============================] - 0s 22us/sample - loss: 0.1697 - accuracy: 0.9447 - val_loss: 0.2852 - val_accuracy: 0.8854
# Epoch 28/40
# 15000/15000 [==============================] - 0s 20us/sample - loss: 0.1635 - accuracy: 0.9475 - val_loss: 0.2849 - val_accuracy: 0.8852
# Epoch 29/40
# 15000/15000 [==============================] - 0s 21us/sample - loss: 0.1571 - accuracy: 0.9503 - val_loss: 0.2857 - val_accuracy: 0.8844
# Epoch 30/40
# 15000/15000 [==============================] - 0s 22us/sample - loss: 0.1514 - accuracy: 0.9527 - val_loss: 0.2852 - val_accuracy: 0.8865
# Epoch 31/40
# 15000/15000 [==============================] - 0s 21us/sample - loss: 0.1461 - accuracy: 0.9550 - val_loss: 0.2857 - val_accuracy: 0.8859
# Epoch 32/40
# 15000/15000 [==============================] - 0s 21us/sample - loss: 0.1403 - accuracy: 0.9573 - val_loss: 0.2859 - val_accuracy: 0.8867
# Epoch 33/40
# 15000/15000 [==============================] - 0s 21us/sample - loss: 0.1355 - accuracy: 0.9597 - val_loss: 0.2872 - val_accuracy: 0.8871
# Epoch 34/40
# 15000/15000 [==============================] - 0s 21us/sample - loss: 0.1306 - accuracy: 0.9613 - val_loss: 0.2885 - val_accuracy: 0.8870
# Epoch 35/40
# 15000/15000 [==============================] - 0s 21us/sample - loss: 0.1259 - accuracy: 0.9631 - val_loss: 0.2897 - val_accuracy: 0.8871
# Epoch 36/40
# 15000/15000 [==============================] - 0s 21us/sample - loss: 0.1215 - accuracy: 0.9655 - val_loss: 0.2920 - val_accuracy: 0.8856
# Epoch 37/40
# 15000/15000 [==============================] - 0s 21us/sample - loss: 0.1172 - accuracy: 0.9661 - val_loss: 0.2939 - val_accuracy: 0.8856
# Epoch 38/40
# 15000/15000 [==============================] - 0s 21us/sample - loss: 0.1131 - accuracy: 0.9686 - val_loss: 0.2959 - val_accuracy: 0.8860
# Epoch 39/40
# 15000/15000 [==============================] - 0s 20us/sample - loss: 0.1091 - accuracy: 0.9698 - val_loss: 0.2978 - val_accuracy: 0.8845
# Epoch 40/40
# 15000/15000 [==============================] - 0s 20us/sample - loss: 0.1050 - accuracy: 0.9709 - val_loss: 0.3005 - val_accuracy: 0.8845

# %%
results = model.evaluate(test_data, test_labels)
# Out:
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
results
# Out:
# [0.3204781254243851, 0.87288]

# %%
test_review = test_data[0]

predict = model.predict([test_review])

# %%
print("Review: ")
# print(decode_review(test_review))
print("Prediction: " + str(predict[0]))
print("Actual: " + str(test_labels[0]))
print(results)
# Out:
# Review:
# Prediction: [0.]
# Actual: 0
# [0.3204781254243851, 0.87288]
